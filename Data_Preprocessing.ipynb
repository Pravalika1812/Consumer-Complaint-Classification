# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravalika1812/Consumer-Complaint-Classification/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
import numpy as np

# %%
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
file_path = '/content/drive/MyDrive/DATA/complaints.csv'

# %%
df = pd.read_csv(file_path)
# Out:
# <ipython-input-5-47c250c455f0>:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (4858723, 18)

# %%
df.head()
# Out:
#   Date received                                            Product  \
# 0    2024-02-28                              Vehicle loan or lease
# 1    2024-02-28                                    Debt collection
# 2    2024-02-29                                           Mortgage
# 3    2024-02-29  Money transfer, virtual currency, or money ser...
# 4    2024-02-29                        Checking or savings account
#
#                     Sub-product                              Issue  \
# 0                          Loan         Managing the loan or lease
# 1              Credit card debt  Attempts to collect debt not owed
# 2    Conventional home mortgage         Struggling to pay mortgage
# 3  International money transfer          Other transaction problem
# 4              Checking account                Managing an account
#
#                                            Sub-issue  \
# 0                                    Billing problem
# ...

# %%
df[500:1000]
# Out:
#     Date received                                            Product  \
# 500    2024-02-28  Credit reporting or other personal consumer re...
# 501    2024-02-28  Credit reporting or other personal consumer re...
# 502    2024-02-28  Credit reporting or other personal consumer re...
# 503    2024-02-28  Credit reporting or other personal consumer re...
# 504    2024-02-22  Credit reporting or other personal consumer re...
# ..            ...                                                ...
# 995    2024-03-04                                    Debt collection
# 996    2024-03-06  Credit reporting or other personal consumer re...
# 997    2024-03-06  Credit reporting or other personal consumer re...
# 998    2024-02-26  Credit reporting or other personal consumer re...
# 999    2024-02-26  Credit reporting or other personal consumer re...
#
#           Sub-product                                              Issue  \
# ...

# %%
df['Sub-product'].value_counts()
# Out:
# Sub-product
# Credit reporting                              2840868
# Checking account                               222635
# General-purpose credit card or charge card     188350
# I do not know                                  124075
# Other debt                                     106416
#                                                ...
# Transit card                                       37
# Earned wage access                                 24
# Student loan debt relief                           19
# Electronic Benefit Transfer / EBT card             12
# Tax refund anticipation loan or check               7
# Name: count, Length: 86, dtype: int64

# %%
df_sorted = df.sort_values('Date received')
df_sorted.head()
# Out:
#         Date received      Product   Sub-product  \
# 4793448    2011-12-01  Credit card           NaN
# 3879949    2011-12-01  Credit card           NaN
# 4222909    2011-12-01  Credit card           NaN
# 626957     2011-12-01     Mortgage  FHA mortgage
# 4068181    2011-12-01  Credit card           NaN
#
#                                             Issue Sub-issue  \
# 4793448                          Billing disputes       NaN
# 3879949                          Credit reporting       NaN
# 4222909                      Credit determination       NaN
# 626957   Loan servicing, payments, escrow account       NaN
# 4068181                         Billing statement       NaN
#
#         Consumer complaint narrative Company public response  \
# 4793448                          NaN                     NaN
# 3879949                          NaN                     NaN
# 4222909                          NaN                     NaN
# ...

# %%
df['Issue'][0]
# Out:
# 'Managing the loan or lease'

# %%
df.loc[504]['Consumer complaint narrative']
# Out:
# 'Company performed a hard inquiry that I need removed immediately unless they provide proof of my authorization.'

# %%
df['Product'].unique()
# Out:
# array(['Vehicle loan or lease', 'Debt collection', 'Mortgage',
#        'Money transfer, virtual currency, or money service',
#        'Checking or savings account', 'Credit card',
#        'Credit reporting or other personal consumer reports',
#        'Student loan',
#        'Payday loan, title loan, personal loan, or advance loan',
#        'Prepaid card', 'Debt or credit management',
#        'Credit reporting, credit repair services, or other personal consumer reports',
#        'Credit card or prepaid card', 'Credit reporting',
#        'Payday loan, title loan, or personal loan', 'Payday loan',
#        'Consumer Loan', 'Bank account or service', 'Money transfers',
#        'Other financial service', 'Virtual currency'], dtype=object)

# %%
df['Product'].unique().size
# Out:
# 21

# %%
category_mapping = {
    'Credit reporting or other personal consumer reports': 'credit_reporting',
    'Checking or savings account': 'retail_banking',
    'Credit reporting, credit repair services, or other personal consumer reports': 'credit_reporting',
    'Debt collection': 'debt_collection',
    'Payday loan, title loan, or personal loan': 'mortgages_and_loans',
    'Credit card or prepaid card': 'credit_card',
    'Mortgage': 'mortgages_and_loans',
    'Credit card': 'credit_card',
    'Payday loan, title loan, personal loan, or advance loan': 'mortgages_and_loans',
    'Student loan': 'mortgages_and_loans',
    'Vehicle loan or lease': 'mortgages_and_loans',
    'Money transfer, virtual currency, or money service': 'retail_banking',
    'Prepaid card': 'credit_card',
    'Debt or credit management': 'debt_collection',
    'Bank account or service': 'retail_banking',
    'Credit reporting': 'credit_reporting',
    'Consumer Loan': 'mortgages_and_loans',
    'Other financial service': 'other_services',
    'Payday loan': 'mortgages_and_loans',
    'Money transfers': 'retail_banking',
    'Virtual currency': 'retail_banking'
}

# %%
df = df.rename(columns={"Product": "product", "Consumer complaint narrative": "narrative"})

# %%
df.head()
# Out:
#   Date received                                            product  \
# 0    2024-02-28                              Vehicle loan or lease
# 1    2024-02-28                                    Debt collection
# 2    2024-02-29                                           Mortgage
# 3    2024-02-29  Money transfer, virtual currency, or money ser...
# 4    2024-02-29                        Checking or savings account
#
#                     Sub-product                              Issue  \
# 0                          Loan         Managing the loan or lease
# 1              Credit card debt  Attempts to collect debt not owed
# 2    Conventional home mortgage         Struggling to pay mortgage
# 3  International money transfer          Other transaction problem
# 4              Checking account                Managing an account
#
#                                            Sub-issue narrative  \
# 0                                    Billing problem       NaN
# ...

# %%
df['Sub-product'].unique()
# Out:
# array(['Loan', 'Credit card debt', 'Conventional home mortgage',
#        'International money transfer', 'Checking account',
#        'General-purpose credit card or charge card', 'Credit reporting',
#        'Telecommunications debt', 'Other debt', 'I do not know',
#        'Private student loan', 'Auto debt', 'Medical debt',
#        'Other personal consumer report', 'Domestic (US) money transfer',
#        'Check cashing service', 'Mobile or digital wallet',
#        'Other banking product or service', 'Rental debt', 'FHA mortgage',
#        'Lease', 'Store credit card', 'CD (Certificate of Deposit)',
#        'Savings account', 'Mortgage debt',
#        'Home equity loan or line of credit (HELOC)',
#        'Federal student loan servicing', 'Installment loan',
#        'Payday loan debt', 'General-purpose prepaid card',
#        'Foreign currency exchange', 'Federal student loan debt',
#        'Payroll card', 'VA mortgage', 'Personal line of credit',
# ...

# %%
df['product_category'] = df['product'].map(category_mapping)

# %%
df.head()
# Out:
#   Date received                                            product  \
# 0    2024-02-28                              Vehicle loan or lease
# 1    2024-02-28                                    Debt collection
# 2    2024-02-29                                           Mortgage
# 3    2024-02-29  Money transfer, virtual currency, or money ser...
# 4    2024-02-29                        Checking or savings account
#
#                     Sub-product                              Issue  \
# 0                          Loan         Managing the loan or lease
# 1              Credit card debt  Attempts to collect debt not owed
# 2    Conventional home mortgage         Struggling to pay mortgage
# 3  International money transfer          Other transaction problem
# 4              Checking account                Managing an account
#
#                                            Sub-issue narrative  \
# 0                                    Billing problem       NaN
# ...

# %%
df['product'].value_counts()
# Out:
# product
# Credit reporting, credit repair services, or other personal consumer reports    2163883
# Credit reporting or other personal consumer reports                              701923
# Debt collection                                                                  545768
# Mortgage                                                                         394655
# Credit card or prepaid card                                                      206374
# Checking or savings account                                                      205339
# Credit reporting                                                                 140429
# Credit card                                                                      122269
# Bank account or service                                                           86205
# Student loan                                                                      85967
# Money transfer, virtual currency, or money service                                65996
# ...

# %%
df['product_category'].value_counts()
# Out:
# product_category
# credit_reporting       3006235
# mortgages_and_loans     605974
# debt_collection         546559
# retail_banking          362912
# credit_card             335985
# other_services            1058
# Name: count, dtype: int64

# %%
# Count how many rows have NaN values in the 'narrative' column
nan_count = df['narrative'].isna().sum()

# %%
nan_count
# Out:
# 3131770

# %%
df_cleaned = df.dropna(subset=['narrative'])

# %%
df_cleaned.shape
# Out:
# (1726953, 19)

# %%
df_cleaned['product'].value_counts()
# Out:
# product
# Credit reporting, credit repair services, or other personal consumer reports    807297
# Debt collection                                                                 237452
# Credit reporting or other personal consumer reports                             146281
# Mortgage                                                                        114387
# Credit card or prepaid card                                                     108669
# Checking or savings account                                                      89149
# Student loan                                                                     40766
# Money transfer, virtual currency, or money service                               37632
# Credit card                                                                      34343
# Credit reporting                                                                 31587
# Vehicle loan or lease                                                            29056
# ...

# %%
df_cleaned['product_category'].value_counts()
# Out:
# product_category
# credit_reporting       985165
# debt_collection        237814
# mortgages_and_loans    214412
# credit_card            146091
# retail_banking         143179
# other_services            292
# Name: count, dtype: int64

# %%
df_cleaned.head()
# Out:
#     Date received                                            product  \
# 33     2024-02-28  Money transfer, virtual currency, or money ser...
# 45     2024-01-23  Credit reporting or other personal consumer re...
# 46     2024-01-24  Credit reporting or other personal consumer re...
# 93     2024-02-28                        Checking or savings account
# 117    2024-01-16  Credit reporting or other personal consumer re...
#
#                       Sub-product  \
# 33   Domestic (US) money transfer
# 45               Credit reporting
# 46               Credit reporting
# 93               Checking account
# 117              Credit reporting
#
#                                                  Issue  \
# 33                                       Fraud or scam
# 45                Incorrect information on your report
# 46                Incorrect information on your report
# 93   Problem with a lender or other company chargin...
# 117  Problem with a company's investigation into an...
#
# ...

# %%
df_cleaned = df_cleaned[['Date received','narrative','product_category']]

# %%
df_cleaned[:10]
# Out:
#     Date received                                          narrative  \
# 33     2024-02-28  This is the original complaint I filed. I coul...
# 45     2024-01-23  Please see identity theft report. I have consi...
# 46     2024-01-24  I reviewed my consumer reports and noticed tha...
# 93     2024-02-28  during the month of XX/XX/XXXX i had XXXX XXXX...
# 117    2024-01-16  I am writing to express my profound dissatisfa...
# 126    2024-01-16  Once again experian sends me another ridiculou...
# 131    2024-01-16  Dear Experian : I have contacted the furnisher...
# 132    2024-01-16  It is a violation to report transaction histor...
# 146    2024-01-23  I have recently examined a copy of my credit r...
# 194    2024-01-15  I am lodging a complaint once again to notify ...
#
#      product_category
# 33     retail_banking
# 45   credit_reporting
# 46   credit_reporting
# 93     retail_banking
# 117  credit_reporting
# 126  credit_reporting
# 131  credit_reporting
# ...

# %%
print(df_cleaned["narrative"].value_counts())
# Out:
# narrative
# ...

# %%
unique_data = df_cleaned['narrative'].unique()

# %%
unique_data = df_cleaned.drop_duplicates(subset='narrative', keep='first')

# %%
unique_data.shape
# Out:
# (1421373, 3)

# %%
unique_data
# Out:
#         Date received                                          narrative  \
# 33         2024-02-28  This is the original complaint I filed. I coul...
# 45         2024-01-23  Please see identity theft report. I have consi...
# 46         2024-01-24  I reviewed my consumer reports and noticed tha...
# 93         2024-02-28  during the month of XX/XX/XXXX i had XXXX XXXX...
# 117        2024-01-16  I am writing to express my profound dissatisfa...
# ...               ...                                                ...
# 4858560    2021-10-16  I sent Capital One written correspondent about...
# 4858605    2021-10-26  On XXXX I applied for a home improvement loan ...
# 4858639    2022-02-11  On XX/XX/XXXX, at approximately XXXX. EST, I r...
# 4858644    2022-02-15  I have an injury committed by GENERAL MOTORS F...
# 4858693    2022-02-24  I am tired of the run around from XXXX XXXX in...
#
#             product_category
# 33            retail_banking
# 45          credit_reporting
# ...

# %%
unique_data['product_category'].value_counts()
# Out:
# product_category
# credit_reporting       702177
# debt_collection        224855
# mortgages_and_loans    213449
# retail_banking         142704
# credit_card            137897
# other_services            291
# Name: count, dtype: int64

# %%
unique_data = unique_data[unique_data['product_category'] != 'other_services']

# %%
min_count = unique_data['product_category'].value_counts().min()

# Create a DataFrame with randomly sampled entries for each category
df_filtered = unique_data.groupby('product_category').apply(lambda x: x.sample(min_count, random_state=42))

print(df_filtered['product_category'].value_counts())
# Out:
# product_category
# credit_card            137897
# credit_reporting       137897
# debt_collection        137897
# mortgages_and_loans    137897
# retail_banking         137897
# Name: count, dtype: int64

# %%
df_filtered = df_filtered.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stopwords_list = stopwords.words('english') + list(string.punctuation)
stopwords_list += ["''", '""', '...', '``']
stopwords_list += ['--', 'xxxx']

# %%
def process_narrative(narrative):
    if not isinstance(narrative, str):
        return narrative  # Return the original value if not a string

    tokens = nltk.word_tokenize(narrative)
    stopwords_removed = [token.lower() for token in tokens if token.lower() not in stopwords_list]
    stopwords_punc_and_numbers_removed = [word for word in stopwords_removed if word.isalpha()]
    return stopwords_punc_and_numbers_removed

# %%
# function to tokenize data and remove stopwords
def process_narrative(narrative):
    tokens = nltk.word_tokenize(narrative)
    stopwords_removed = [token.lower() for token in tokens if token.lower() not in stopwords_list]

    # remove tokens with numbers and punctuation
    stopwords_punc_and_numbers_removed = [word for word in stopwords_removed if word.isalpha()]

    return stopwords_punc_and_numbers_removed

# %%
for i in range(len(df_filtered)):
    processed_narr = process_narrative(df_filtered['narrative'].iloc[i])
    df_filtered['narrative'].iloc[i] = processed_narr
    if i % 3000 == 0:
        print(f'Finished line number {i}')
df_filtered.head()
# Out:
# Finished line number 0
# Finished line number 3000
# Finished line number 6000
# Finished line number 9000
# Finished line number 12000
# Finished line number 15000
# Finished line number 18000
# Finished line number 21000
# Finished line number 24000
# Finished line number 27000
# Finished line number 30000
# Finished line number 33000
# Finished line number 36000
# Finished line number 39000
# Finished line number 42000
# Finished line number 45000
# Finished line number 48000
# Finished line number 51000
# Finished line number 54000
# Finished line number 57000
# Finished line number 60000
# Finished line number 63000
# Finished line number 66000
# Finished line number 69000
# Finished line number 72000
# Finished line number 75000
# Finished line number 78000
# Finished line number 81000
# Finished line number 84000
# Finished line number 87000
# Finished line number 90000
# Finished line number 93000
# Finished line number 96000
# Finished line number 99000
# ...

# %%
df_filtered = df_filtered.reset_index(drop=True)
df_filtered['narrative'] = df_filtered['narrative'].apply(lambda word_list: ' '.join(word_list))

# %%
df_filtered.head()

# %%
df_filtered['narrative'][0]
# Out:
# ['events',
#  'remember',
#  'additional',
#  'phone',
#  'calls',
#  'local',
#  'branch',
#  'listed',
#  'nothing',
#  'happened',
#  'opened',
#  'four',
#  'savings',
#  'accounts',
#  'one',
#  'checking',
#  'account',
#  'using',
#  'checks',
#  'payable',
#  'child',
#  'chase',
#  'bank',
#  'checks',
#  'cleared',
#  'account',
#  'wrote',
#  'checks',
#  'around',
#  'received',
#  'letter',
#  'mail',
#  'one',
#  'savings',
#  'accounts',
#  'stating',
#  'account',
#  'going',
#  'closed',
#  'called',
#  'number',
#  'letter',
#  'guy',
#  'said',
#  'monies',
#  'appeared',
#  'fraud',
#  'explaining',
#  'children',
#  'work',
#  'family',
#  'business',
#  'check',
#  'written',
#  'business',
#  'account',
#  'said',
#  'able',
#  'verify',
#  'needed',
#  'go',
#  'local',
#  'bank',
#  'office',
#  'reopen',
#  'new',
#  'accounts',
#  'funds',
#  'could',
#  'transferred',
#  'holding',
#  'tank',
#  'put',
#  'new',
#  'savings',
#  'accounts',
# ...

# %%
df_filtered['product_category'].value_counts()
# Out:
# product_category
# retail_banking         137897
# debt_collection        137897
# mortgages_and_loans    137897
# credit_card            137897
# credit_reporting       137897
# Name: count, dtype: int64

# %%
df_filtered.to_csv('/content/drive/MyDrive/NLP/NLP_PROJECT3/complaints_preprocessed_and_balanced_data.csv')

# %%
# Define the date range
start_date = '2021-10-01'
end_date = '2024-02-04'

filtered_df = df_filtered[(df_filtered['Date received'] >= start_date) & (df_filtered['Date received'] <= end_date)]

# %%
filtered_df.shape
# Out:
# (291913, 3)

# %%
filtered_df[:20]
# Out:
#    Date received                                          narrative  \
# 0     2023-05-24  [events, remember, additional, phone, calls, l...
# 5     2023-02-04  [remember, date, might, earlier, asked, wells,...
# 6     2023-12-31  [scheduled, auto, payment, email, came, today,...
# 11    2023-06-13  [accordance, fair, credit, reporting, act, lis...
# 14    2021-12-22  [husband, promised, lender, credit, receive, p...
# 20    2022-08-10  [ordered, copy, report, found, credit, reporti...
# 23    2022-04-01  [refinanced, new, day, financial, promised, pa...
# 28    2023-04-11  [company, name, account, holder, wire, routing...
# 32    2023-04-03  [would, like, remaining, funds, inside, closed...
# 36    2023-03-21  [notice, sent, ira, account, contacted, said, ...
# 37    2022-02-08  [truist, suntrust, mortgage, lender, loss, mit...
# 43    2023-04-17  [accordance, fair, credit, reporting, act, lis...
# 44    2022-11-18  [company, xxxxxxxx, transunion, consumer, solu...
# ...

# %%
filtered_df['product_category'].value_counts()
# Out:
# product_category
# credit_reporting       83046
# retail_banking         66890
# credit_card            56729
# debt_collection        44848
# mortgages_and_loans    40400
# Name: count, dtype: int64

# %%
min_count = filtered_df['product_category'].value_counts().min()

# Create a DataFrame with randomly sampled entries for each category
filtered_df = filtered_df.groupby('product_category').apply(lambda x: x.sample(min_count, random_state=42))

filtered_df = filtered_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
filtered_df['product_category'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-552ff308de91> in <cell line: 1>()
# ----> 1 filtered_df['product_category'].value_counts()
#
# NameError: name 'filtered_df' is not defined

# %%
filtered_df.shape
# Out:
# (202000, 3)

# %%
filtered_df.head()
# Out:
#   Date received                                          narrative  \
# 0    2022-06-26  [checked, credit, score, using, saw, score, re...
# 1    2023-05-17  [receipt, response, complaint, please, advised...
# 2    2023-08-22  [filed, recent, complaints, movement, mortgage...
# 3    2023-06-22  [went, onto, look, auto, refinance, loan, offe...
# 4    2022-02-14  [repeatedly, asked, caliber, home, loans, chan...
#
#       product_category
# 0      debt_collection
# 1     credit_reporting
# 2  mortgages_and_loans
# 3  mortgages_and_loans
# 4  mortgages_and_loans

# %%
count = 140000

# Create a DataFrame with randomly sampled entries for each category
trainData = filtered_df.sample(count, random_state=42).reset_index(drop=True)

print(trainData['product_category'].value_counts())
# Out:
# product_category
# credit_card            28102
# debt_collection        28097
# retail_banking         27994
# credit_reporting       27936
# mortgages_and_loans    27871
# Name: count, dtype: int64

# %%
count = 5000

# Create a DataFrame with randomly sampled entries for each category
testData = filtered_df.sample(count, random_state=42).reset_index(drop=True)

print(testData['product_category'].value_counts())
# Out:
# product_category
# retail_banking         1031
# credit_reporting       1028
# debt_collection         990
# mortgages_and_loans     979
# credit_card             972
# Name: count, dtype: int64

# %%
trainData.to_csv('/content/drive/MyDrive/NLP/NLP_PROJECT3/filtered_complaints_train_data.csv')
testData.to_csv('/content/drive/MyDrive/NLP/NLP_PROJECT3/filtered_complaints_test_data.csv')
